# %% [markdown]
#  # What is Machine Learning?
#  To solve real-life analytical problems, our initial approach is using a form of simple analysis and ask the right questions.
#
#
# ## When do we use machine learning?
# ###  Machine learning examples
#
# ## Dont trust machine learning blindly
#
# ## Data Scientists are detectives
